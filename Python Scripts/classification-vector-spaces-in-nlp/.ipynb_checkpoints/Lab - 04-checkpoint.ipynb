# %% [markdown]
# ### Laboratório 4
#
# Nesse laboratório, o objetivo será preparar um pequeno sistema de tradução. Para desenvolver esse sistema alguns conceitos serão trabalhados.
#
# O primeiro deles é projeção. É possível projetar um vetor $v \in V$, onde $V$ é um espaço vetorial em outro espaço vetorial $W$. Para fazermos isso, precisamos realizar uma transformação em $v$, tal transformação pode ser definida por $w = pv^{t}, w \in W$.
#
# Entendendo isso, é sabido que existe a seguinte relação:
# $$W = VP$$
#
# A pergunta então, é como encontrar R. Ora, R pode ser encontrado atravéz da descida de gradiente, técnica conhecida para minimização. Qual a função objetivo nesse caso ?
# $$Loss = ||VP - W||_{f}$$
#
# Onde $||||_{f}$ equivale a norma de Forbenius, representada pela raiz quadrada da soma dos quadrados de todos os termos da matriz, ou $||A||_{f} = \sqrt{\sum_{i}{\sum_{j}}{a_{i,j}^{2}}}$. Agora que já sabemos a função a ser minimizada, devemos definir o gradiente da mesma.
#
# $$\nabla Loss = \frac{\delta Loss}{\delta P} = \frac{2 V^{t}(VP - W)}{m}$$
#
# Agora com o algoritmo de descida de gradiente é possível encontrar P. Ainda assim, a relação $W = VP$ não é verdadeira, no caso temos a relação $W \approx VP$. O que implica que mesmo achando VP, devemos utilizar algum algoritmo que encontre a equivalência entre as palavras.
#
# Adianto que o algoritmo usado será o KNN, e como não é nada novo pra mim, vou pular essa parte.
#
# ### Locally sensitive hashing
#
# Esse tipo de hashing é interessante porque ao invés de agrupar os termos por modulo, ela na verdade agrupa os termos por regiões no espaço vetorial. Para definir
#
# $$  $$
#
# O experimento que vou fazer aqui tem como objetivo testar esse algoritmo de tradução. Na bíblia hebraíca. kkkkk

# %%
import urllib.request
import urllib.parse
import re
import numpy as np
import nltk
from nltk.corpus import stopwords
def normalize(vec):
    return vec/(np.linalg.norm(vec))
def cos(vec,wec):
    return np.dot(vec,wec)/(np.linalg.norm(vec)*np.linalg.norm(wec))

import re
try: 
    from BeautifulSoup import BeautifulSoup
except ImportError:
    from bs4 import BeautifulSoup
hebrewCorpus = []
maxRange = 30
for index in range(1,maxRange):
    url = "https://biblehub.com/wlco/genesis/"+str(index)+".htm"
    response = urllib.request.urlopen(url)
    if(response.status < 300):
        contents = response.read()
        contents = contents.decode("utf-8")
        parsed_html = BeautifulSoup(contents)
        htmlTextArray = parsed_html.body.find_all('span', attrs={'class':'spcl'})
        textArray = [ele.text for ele in htmlTextArray]
        hebrewCorpus += textArray

        engCorpus = []
for index in range(1,maxRange):
    url = "https://biblehub.com/web/genesis/"+str(index)+".htm"
    response = urllib.request.urlopen(url)
    if(response.status < 300):
        contents = response.read()
        contents = contents.decode("utf-8")
        parsed_html = BeautifulSoup(contents)
        htmlTextArray = parsed_html.body.find_all('p', attrs={'class':'reg'})
        removeSpaces = [re.sub("\n|\r","",ele.text) for ele in htmlTextArray]
        textArray = []
        for text in removeSpaces:
            aux = re.sub("\d+","*",text)
            aux = aux.split("*")
            for text_ in aux:
                if text_ != '':
                    textArray += [text_]
        engCorpus += textArray
        
portugCorpus = []
for index in range(1,maxRange):
    url = "https://bibliaportugues.com/kja/genesis/"+str(index)+".htm"
    response = urllib.request.urlopen(url)
    if(response.status < 300):
        contents = response.read()
        contents = contents.decode("utf-8")
        parsed_html = BeautifulSoup(contents)
        htmlTextArray = parsed_html.body.find_all('span', attrs={'class':'maintext'})
        textArray = [ele.text for ele in htmlTextArray]
        portugCorpus += textArray

#nltk.download('punkt')
#nltk.download('stopwords')

# %%
pontuacao = [",",".",":",";","?","!","(",")","&","“", "”","\"","'",'']
palavrasIrrelevantes = [str(line).split(" ")[0] for line in open("./palavrasIrrelevantes.txt", encoding="utf-8")]
palavrasIrrelevantesHb = [str(line) for line in open("./palavrasIrrelevantesHb.txt", encoding="utf-8")]
palavrasIrrelevantesEng = [str(line).replace("\n","") for line in open("./palavrasIrrelevantesEng.txt", encoding="utf-8")]
vocabularioPtbr = {}
vocabularioHebrew = {}
vocabularioEng = {}
maxWords = 10000

def criarTokensBr(frase):
    fraseTokenizada = nltk.word_tokenize(frase.lower())
    return [word for word in fraseTokenizada if word not in stopwords.words('portuguese') and word not in pontuacao]

def criarTokensEng(frase):
    fraseTokenizada = nltk.word_tokenize(frase.lower())
    return [word for word in fraseTokenizada if word not in stopwords.words('english')and word not in pontuacao]

def criarTokensHb(frase):
    fraseTokenizada = nltk.word_tokenize(frase.lower())
    return fraseTokenizada

def criarVocabulario(corpo,vocabulario,criarTokens):
    index = 0
    for frase in corpo:
        fraseTokenizada = []
        fraseTokenizada = criarTokens(frase)
        for i in range((len(fraseTokenizada))):
            if fraseTokenizada[i] not in vocabulario.keys():
                vocabulario[fraseTokenizada[i]] = index
                index += 1
                if(index == maxWords):
                    return vocabulario
    return vocabulario
            
vocabularioPtbr = criarVocabulario(portugCorpus,vocabularioPtbr, criarTokensBr)
vocabularioEng = criarVocabulario(engCorpus,vocabularioEng, criarTokensEng)

# %%
len(vocabularioPtbr),len(vocabularioEng)
# Out:
# (3027, 1570)

# %%
lenVoc = len(vocabularioPtbr)
coOcBr = np.zeros((lenVoc, lenVoc))
coOcBr.shape

def knnModificado(corpus, vocab, criarTokens, matriz, k=2):
    for frase in corpus:
        tokens = criarTokens(frase)
        for i in range(len(tokens)):
            for j in range(i+1,len(tokens)):
                if(tokens[i] not in vocab.keys() or tokens[j] not in vocab.keys()):
                    continue
                if(abs(i - j) <= k):
                    matriz[vocab[tokens[i]],vocab[tokens[j]]] += 1
                    matriz[vocab[tokens[j]],vocab[tokens[i]]] += 1
                    
knnModificado(portugCorpus, vocabularioPtbr, criarTokensBr,coOcBr, k = 64)

# %%
coOcTarget = np.zeros((lenVoc, lenVoc))
coOcTarget.shape
knnModificado(engCorpus, vocabularioEng, criarTokensEng, coOcTarget,k= 64)

# %%
coOcBr.shape, coOcTarget.shape
# Out:
# ((3027, 3027), (3027, 3027))

# %%
W = coOcTarget
V = coOcBr

# %%
def aplicarSVD(matrizCoocorrencia):
    return np.linalg.svd(np.cov(matrizCoocorrencia - np.mean(matrizCoocorrencia, axis=0)), full_matrices=True)

WU, WS, WV = aplicarSVD(W)
print(WU.shape, WS.shape, WV.shape)
# Out:
# (3027, 3027) (3027,) (3027, 3027)

# %%
VU, VS, VV = aplicarSVD(V)
print(VU.shape, VS.shape, VV.shape)
# Out:
# (3027, 3027) (3027,) (3027, 3027)

# %%
def aplicarPCA(U, X, k=100):
    return np.dot(U[:,:k].transpose(), (X - np.mean(X, axis=0)).transpose()).transpose()
dim = 100
Wr = aplicarPCA(WU,W, k=dim) 
Vr = aplicarPCA(VU,V, k=dim) 
P = None
print(Wr.shape, Vr.shape)
# Out:
# (3027, 100) (3027, 100)

# %%
cos(Vr[vocabularioPtbr["deus".lower()],:], Vr[vocabularioPtbr["abraão".lower()],:])
# Out:
# 0.6485939718555978

# %%
cos(Wr[vocabularioEng["god".lower()],:], Wr[vocabularioEng["abraham".lower()],:])
# Out:
# 0.7539701881722263

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(figsize=(15,5))
#ax.set_xlim([10,20])
#ax.set_ylim([-10,10])
ax.scatter(Vr[:,0], Vr[:,1])
for text, index in vocabularioPtbr.items():
    ax.annotate(text, (Vr[index,0],Vr[index,1]))

# %% [markdown]
# Acima uma representação das palavras considerando a redução de dimensionalidade. Pela quantidade de palavras é bem complicado notar alguma coisa, mas podemos diminuir e ver alguns exemplos simples.

# %%
from IPython.display import clear_output

def decidaGradiente(W, V, lr=0.5, it= 100, P = None):
    if P is None:
        P = np.random.normal(size=(V.shape[1], V.shape[1]))
    losses = []
    for i in range(it):
        toMin = np.dot(V,P) - W
        loss = np.linalg.norm(toMin, ord='fro')
        losses.append(loss)
        if(len(losses) > 2 and losses[i-1] - losses[i]<= 0.1):
            return P
        clear_output(wait=False)
        print("Iteracao",i,loss)
        grad = (np.dot(2*V.transpose(),toMin))
        grad = grad/V.shape[0]
        P = P - grad * lr        
    return P

P = decidaGradiente(Wr,Vr, it=25000,lr=.00005, P=P)
# Out:
# Iteracao 7092 2456.538501907158

# %%
palavras = np.dot(Vr[3],P)
palavras.shape, P.shape
# Out:
# ((100,), (100, 100))

# %%
reverseVocabularioEng = dict([(value,key) for key,value in vocabularioEng.items()])
def traduzir(palavra,P,Vr,Wr):
    tokens = criarTokensBr(palavra)
    if(len(tokens) == 0):
        return ""
    palavra = tokens[0]
    if palavra not in vocabularioPtbr.keys():
        return "Indefinido"
    projecao = np.dot(Vr[vocabularioPtbr[palavra]],P)
    dist = 0
    index = 0
    for key, value in vocabularioEng.items():
        if key not in vocabularioEng.keys():
            return "Indefinido"
        newdist = cos(projecao, Wr[vocabularioEng[key],:])
        if(dist < newdist):
            dist = newdist
            index = key 
    return index

traduzir("senhor",P,Vr,Wr)
# Out:
# 'ur'

# %%
def traduzirFrase(frase):
    result = ""
    print("\n" + frase)
    for palavra in frase.split(" "):
        val = traduzir(palavra,P,Vr,Wr)
        if len(val) != 0:
            result += val + " "    
    print(result)
    
for verso in portugCorpus:
    traduzirFrase(verso)
# Out:
# No princípio, Deus criou os céus e a terra.
# in and god the heavens and earth . for
#
# A terra, entretanto, era sem forma e vazia. A escuridão cobria o mar que envolvia toda a terra, e o Espírito de Deus se movia sobre a face das águas.
# . for were of formed of earth of . of of 's rain good of waters . for earth 's eden , god `` waters and . times darkness ''
#
# Disse Deus: “Haja luz!”, e houve luz.
#
# Homem e mulher os criou, e os abençoou e lhes deu o nome de Humanos.
# herb earth lived heavens the earth heavens in earth birds ever 's heavens , birds
#
# Quando Adão completou cento e trinta anos, gerou um filho à sua semelhança, como sua imagem, e lhe deu o nome de Sete.
# adam sign go mouth earth planted female face a morning is up wise voice up sort earth walking ever 's heavens , surface
#
# O tempo que viveu Adão depois do nascimento de Sete foi de oitocentos anos, e gerou filhos e filhas.
# 's to good divided sign ; sons prevailed , surface , , divided female earth face swarmed earth cursed
#
# Toda a duração da vida de Adão foi de novecentos e trinta anos; depois morreu.
# waters . ; . garden , sign , , over earth planted female ; ;
#
# Quando Sete completou cento e cinco anos, gerou Enos.
# adam surface go mouth earth handle female face good
#
# Depois do nascimento de Enos, Sete viveu oitocentos e sete anos, e gerou filhos e filhas.
# ; sons prevailed , good surface divided divided earth surface female earth face swarmed earth cursed
#
# Toda a duração da vida de Sete foi de novecentos e doze anos; depois morreu.
# waters . ; . garden , surface , , over earth another female ; ;
#
# Quando Enos completou noventa anos, gerou Cainã.
# adam good go window female face until
#
# Depois do nascimento de Cainã, Enos viveu oitocentos e quinze anos, e gerou filhos e filhas.
# ; sons prevailed , until good divided divided earth length female earth face swarmed earth cursed
#
# Toda a duração da vida de Enos foi de novecentos e cinco anos; depois morreu.
# waters . ; . garden , good , , over earth handle female ; ;
#
# Quando Cainã completou setenta anos, gerou Maalaleel.
# adam until go named female face water
#
# Depois do nascimento de Maalaleel, Cainã viveu oitocentos e quarenta anos, e gerou filhos e filhas.
# ; sons prevailed , water until divided divided earth so female earth face swarmed earth cursed
#
# Toda a duração da vida de Cainã foi de novecentos e dez anos; depois morreu.
# waters . ; . garden , until , , over earth signs female ; ;
#
# Quando Maalaleel completou sessenta e cinco anos, gerou Jarede.
# adam water go subdue earth handle female face yourself
#
# Depois do nascimento de Jarede, Maalaleel viveu oitocentos e trinta anos, e gerou filhos e filhas.
# ; sons prevailed , yourself water divided divided earth planted female earth face swarmed earth cursed
#
# Toda a duração da vida de Maalaleel foi de oitocentos e noventa e cinco anos; depois morreu.
# waters . ; . garden , water , , divided earth window earth handle female ; ;
#
# Quando Jarede completou cento e sessenta e dois anos, gerou Enoque.
# adam yourself go mouth earth subdue earth you female face so
#
# Depois do nascimento de Enoque, Jarede viveu oitocentos anos e gerou filhos e filhas.
# ; sons prevailed , so yourself divided divided female earth face swarmed earth cursed
#
# Toda a duração da vida de Jarede foi de novecentos e sessenta e dois anos; depois morreu.
# waters . ; . garden , yourself , , over earth subdue earth you female ; ;
#
# Quando Enoque completou sessenta e cinco anos, gerou a Matusalém.
# adam so go subdue earth handle female face . ;
#
# Depois que gerou Matusalém, Enoque andou com Deus mais trezentos anos e gerou filhos e filhas.
# ; good face ; so mother animals god good sevenfold female earth face swarmed earth cursed
#
# Toda a duração da vida de Enoque foi de trezentos e sessenta e cinco anos.
# waters . ; . garden , so , , sevenfold earth subdue earth handle female
#
# Enoque andou sempre em comunhão com Deus e um dia desapareceu, porquanto Deus o arrebatou!
# so mother began to brothers animals god earth a . ' on god 's n't
#
# Quando Matusalém completou cento e oitenta e sete anos, gerou a Lameque.
# Os filhos de Noé, que saíram da arca, foram Sem, Cam e Jafé; Cam é o pai de Canaã.
# heavens swarmed , evil good Indefinido . waters trees formed hands earth off hands he 's nakedness , Indefinido
#
# Esses três foram filhos de Noé e a partir deles se fez o povoamento de toda a terra.
# sixty-five whose trees swarmed , evil earth . Indefinido father `` in 's Indefinido , waters . for
#
# Noé, era cultivador, e foi o primeiro a plantar uma vinha.
# evil of Indefinido earth , 's she . Indefinido multiply Indefinido
#
# Bebeu do vinho que havia feito, embriagou-se e ficou dentro da sua tenda.
# Indefinido sons Indefinido good god awoke Indefinido earth bread awoke . up Indefinido
#
# Cam, pai de Canaã, notou que seu pai estava nu e foi contar aos dois irmãos que estavam do lado de fora.
# hands nakedness , Indefinido Indefinido good god nakedness they blessed earth , Indefinido lights you Indefinido good them sons food , awoke
#
# Então Sem e Jafé tomaram uma capa, levantaram-na sobre os próprios ombros e, andando de costas para não verem a nudez do pai, cobriram-no.
# which formed earth off Indefinido multiply Indefinido Indefinido and heavens Indefinido Indefinido earth Indefinido , Indefinido saying become Indefinido . Indefinido sons nakedness Indefinido
#
# Quando Noé acordou da sua embriaguez, soube do que Cam, seu filho mais jovem, havia feito.
# adam evil Indefinido . up Indefinido Indefinido sons good hands god morning good Indefinido god awoke
#
# Então esbravejou Noé: “Maldito seja Canaã! Escravo de escravos será para seus irmãos”.
# which Indefinido evil it breathed Indefinido Indefinido , Indefinido established saying instrument Indefinido
#
# E acrescentou: “Bendito seja o SENHOR, o Deus de Sem! E seja Canaã seu escravo.
# earth great it breathed 's token 's god , formed earth breathed Indefinido god Indefinido
#
# Que Deus amplie o território de Jafé; habite ele nas tendas de Sem, e seja Canaã seu escravo!”.
# good god Indefinido 's no , off Indefinido woman stayed plant , formed earth breathed Indefinido god Indefinido
#
# Depois do Dilúvio, Noé viveu mais trezentos e cinqüenta anos.
# ; sons tents evil divided good sevenfold earth Indefinido female
#
# Toda a duração da vida de Noé foi de novecentos e cinqüenta anos, depois morreu.
# waters . ; . garden , evil , , over earth Indefinido female ; ;

# %%
def ladoDoPlano(P,v):
    prod = np.dot(P,v.transpose())
    sinais = np.sign(prod)
    return sinais

def hashSensivel(P,v):
    valorHash = 0
    sinais = ladoDoPlano(P,v)
    sinais = (sinais >= 0) * 1
    index = np.sum(2**np.array(range(P.shape[0])) * sinais)
    return index

def criarHashing(P,V,vocabulario):
    reverseVocabulario = dict([(value,key) for key, value in vocabulario.items()])
    hashing = {}
    wordHashing = {}
    for i in range(V.shape[0]):
        vec = V[i]
        index = hashSensivel(P,vec)
        if index in hashing:
            hashing[index].append(vec)
            wordHashing[index].append(reverseVocabulario[i])
        else:
            hashing[index] = [vec]
            wordHashing[index] = [reverseVocabulario[i]]
    return hashing, wordHashing

# %% [markdown]
# ### Conclusão
#
# O método de PCA para grande volume de dados fica bem ruim para tradução. Principalmente considerando o fato de que não estamos usando um texto original. As frequências de palavras acabam sendo muito distintas, o que piora ainda mais a tradução, visto que esse modelo é inteiramente baseado na sequência.
#
# Todavia, foi exercitado o uso de alguns conceitos como decida de gradiente, SVD e PCA... Todos úteis para outras aplicações.
